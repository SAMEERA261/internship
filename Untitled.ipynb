# %% [markdown]
# ### Internship

# %%
import pandas as pd,numpy as np

# %%
movie=pd.read_csv(r"C:\Users\Sam\Downloads\movie_data\movies.csv")

# %%
movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
rating=pd.read_csv(r"C:\Users\Sam\Downloads\movie_data\ratings.csv")

# %%
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rating['userId'].nunique()
# Out:
# 610

# %%
merged_data = pd.merge(movie, rating, on='movieId')

ratings_count = merged_data.groupby('title')['rating'].count().reset_index()

max_rated_movie = ratings_count.loc[ratings_count['rating'].idxmax()]

print("Movie with the maximum number of ratings:")
print(max_rated_movie[['title', 'rating']])
# Out:
# Movie with the maximum number of ratings:
# title     Forrest Gump (1994)
# rating                    329
# Name: 3158, dtype: object

# %%
movie_title = "Matrix, The (1999)"

matrix_movie_id = movie[movie['title'] == movie_title]['movieId'].iloc[0]

matrix_tags = movie[movie['movieId'] == matrix_movie_id]

unique_tags = matrix_tags['title'].unique()
print("Tags submitted by users for 'Matrix, The (1999)':")
print(unique_tags)
# Out:
# Tags submitted by users for 'Matrix, The (1999)':
# ['Matrix, The (1999)']

# %%
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
import pandas as pd


movie_title = "Terminator 2: Judgment Day (1991)"

terminator_movie_id = movie[movie['title'] == movie_title]['movieId'].iloc[0]


terminator_ratings = rating[rating['movieId'] == terminator_movie_id]



average_rating = terminator_ratings['rating'].mean()


print(f"Average user rating for '{movie_title}': {average_rating:.2f}")
# Out:
# Average user rating for 'Terminator 2: Judgment Day (1991)': 3.97

# %%
import pandas as pd
import matplotlib.pyplot as plt


movie_title = "Fight Club (1999)"


fight_club_movie_id = movie[movie['title'] == movie_title]['movieId'].iloc[0]


fight_club_ratings = rating[rating['movieId'] == fight_club_movie_id]

plt.figure(figsize=(10, 6))
plt.hist(fight_club_ratings['rating'], bins=10, edgecolor='black')
plt.title(f'Distribution of User Ratings for "{movie_title}"')
plt.xlabel('Rating')
plt.ylabel('Number of Ratings')
plt.grid(True)
plt.show()

# %%
rating.describe().T
# Out:
#               count          mean           std          min           25%  \
# userId     100836.0  3.261276e+02  1.826185e+02          1.0  1.770000e+02
# movieId    100836.0  1.943530e+04  3.553099e+04          1.0  1.199000e+03
# rating     100836.0  3.501557e+00  1.042529e+00          0.5  3.000000e+00
# timestamp  100836.0  1.205946e+09  2.162610e+08  828124615.0  1.019124e+09
#
#                     50%           75%           max
# userId     3.250000e+02  4.770000e+02  6.100000e+02
# movieId    2.991000e+03  8.122000e+03  1.936090e+05
# rating     3.500000e+00  4.000000e+00  5.000000e+00
# timestamp  1.186087e+09  1.435994e+09  1.537799e+09

# %%
grouped_ratings = rating.groupby('movieId').agg({'rating': ['count', 'mean']}).reset_index()

grouped_ratings.columns = ['movieId', 'rating_count', 'rating_mean']

merged_data = pd.merge(movie, grouped_ratings, on='movieId', how='inner')

filtered_movies = merged_data[merged_data['rating_count'] > 50]

print(filtered_movies)
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# 2                                  Comedy|Romance            52     3.259615
# 5                           Action|Crime|Thriller           102     3.946078
# ...

# %%
most_popular_movie = filtered_movies.loc[filtered_movies['rating_mean'].idxmax()]

print(f"The most popular movie based on average user ratings is:")
print(f"Title: {most_popular_movie['title']}")
print(f"Average Rating: {most_popular_movie['rating_mean']:.2f}")
print(f"Number of Ratings: {most_popular_movie['rating_count']}")
# Out:
# The most popular movie based on average user ratings is:
# Title: Shawshank Redemption, The (1994)
# Average Rating: 4.43
# Number of Ratings: 317

# %%
top5_popular_movies = filtered_movies.nlargest(5, 'rating_count')

print("Top 5 popular movies based on number of user ratings:")
print(top5_popular_movies[['title', 'rating_count']])
# Out:
# Top 5 popular movies based on number of user ratings:
#                                  title  rating_count
# 314                Forrest Gump (1994)           329
# 277   Shawshank Redemption, The (1994)           317
# 257                Pulp Fiction (1994)           307
# 510   Silence of the Lambs, The (1991)           279
# 1938                Matrix, The (1999)           278

# %%
scifi_movies = filtered_movies[filtered_movies['genres'].str.contains('Sci-Fi', case=False, na=False)]

third_most_popular_scifi = scifi_movies.nlargest(3, 'rating_count').iloc[-1]


print(f"The third most popular Sci-Fi movie based on number of user ratings is:")
print(f"Title: {third_most_popular_scifi['title']}")
print(f"Number of Ratings: {third_most_popular_scifi['rating_count']}")
# Out:
# The third most popular Sci-Fi movie based on number of user ratings is:
# Title: Jurassic Park (1993)
# Number of Ratings: 238

# %% [markdown]
# ### i don't have idea of web scraping

# %%
link=pd.read_csv(r"C:\Users\Sam\Downloads\movie_data\links.csv")

# %%
link
# Out:
#       movieId   imdbId    tmdbId  movieId.1  \
# 0      189111  5359048  525662.0     189111
# 1         720   118114  503475.0        720
# 2      184257  5189670  502892.0     184257
# 3      184791  7924798  502616.0     184791
# 4      185135  1665071  500609.0     185135
# ...       ...      ...       ...        ...
# 9737     1107   102336       NaN       1107
# 9738    40697   105946       NaN      40697
# 9739      791   113610       NaN        791
# 9740    32600   377059       NaN      32600
# 9741    79299   874957       NaN      79299
#
#                                                   title  \
# 0                                         Spiral (2018)
# 1     Wallace & Gromit: The Best of Aardman Animatio...
# 2                              Making a Murderer (2015)
# 3             Fred Armisen: Standup for Drummers (2018)
# 4                     Sherlock - A Study in Pink (2010)
# ...                                                 ...
# ...

# %%
text=pd.read_csv(r"C:\Users\Sam\Downloads\movie_data\links.csv")

# %%
text
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]
